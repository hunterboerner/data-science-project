# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt# Load data
from sklearn import linear_model
from sklearn.cluster import KMeans as km
import statsmodels.api as sm

# %matplotlib inline
city_data = pd.read_csv('USData_ClassProject1.csv')

# %%
x = city_data.PercentWhite
y = city_data.MedianHouseholdIncome 
x = sm.add_constant(x)

# %%
clf = linear_model.LinearRegression()
clf.fit(x,y)

y_hat = clf.predict(x)

# %%
plt.scatter(city_data.PercentWhite,city_data.MedianHouseholdIncome,color="Black")
plt.plot(x.PercentWhite, y_hat, 'b', alpha=0.9)

print "R^2: ", clf.score(x,y)
# Out:
# R^2:  0.0318199157966

# %%
print "Mean: " + str(np.mean(city_data.PercentWhite))

print "Median: " + str(np.median(city_data.PercentWhite))

print "Median Population: " + str(np.median(city_data.TotalPopulation))

print "Mean Popluation: " + str(np.mean(city_data.TotalPopulation))
# Out:
# Mean: 65.1329795597
# Median: 71.25
# Median Population: 25590.5
# Mean Popluation: 59279.8533805

# %%
rich_people = city_data[['City','MedianHouseholdIncome','PercentWhite', 'TotalPopulation']][city_data.MedianHouseholdIncome >= 150000]
print "Mean white: " + str(np.mean(rich_people.PercentWhite))
print "Median white: " + str(np.median(rich_people.PercentWhite))
rich_people
# Out:
# Mean white: 73.45
# Median white: 77.5
#                      City  MedianHouseholdIncome  PercentWhite  \
# 306              LosAltos                 151856          66.9
# 352                Orinda                 157500          79.0
# 361    PalosVerdesEstates                 159038          72.7
# 369              Piedmont                 199304          72.6
# 420             SanMarino                 154318          39.4
# 436              Saratoga                 155182          49.6
# 1475       TownandCountry                 161600          85.5
# 2104             Bellaire                 155423          76.0
# 2125          Colleyville                 159982          80.7
# 2270            Southlake                 183441          87.8
# 2285       UniversityPark                 151862          90.0
# 2296  WestUniversityPlace                 186703          81.2
#
#       TotalPopulation
# 306             28752
# 352             17599
# 361             13412
# 369             10640
# 420             13131
# 436             29781
# 1475            10817
# 2104            16751
# 2125            22569
# 2270            26194
# 2285            23076
# 2296            14733

# %%
x = rich_people.PercentWhite
y = rich_people.MedianHouseholdIncome 
x = sm.add_constant(x)

clf = linear_model.LinearRegression()
clf.fit(x,y)

y_hat = clf.predict(x)

plt.scatter(rich_people.PercentWhite,rich_people.MedianHouseholdIncome,color="Black")
plt.plot(x.PercentWhite, y_hat, 'b', alpha=0.9)

print "R^2: ", clf.score(x,y)
# Out:
# R^2:  0.0759858858176

# %% [markdown]
# ##Clustering
#
# Used clustering of white people vs Median Household Income
#
# ###Without Normalization
#
# Clusters are visualy weird. Because income is much more differnt in magnitude then percent of anything with a max of 100.

# %%
def cluster(X):
    clf.fit(X)
    return clf.predict(X)

clf,X = KMeans(3), rich_people[['PercentWhite','MedianHouseholdIncome']]  # 4 clusters


plt.scatter(rich_people.PercentWhite, rich_people.MedianHouseholdIncome, c=cluster(X), s=50)

# %% [markdown]
# ###With Normalization
#
# It makes much more sense. **So use normalization!!!!**

# %%
X.PercentWhite = (X.PercentWhite - np.mean(X.PercentWhite))/np.std(X.PercentWhite)
X.MedianHouseholdIncome = (X.MedianHouseholdIncome - np.mean(X.MedianHouseholdIncome))/np.std(X.MedianHouseholdIncome)

plt.scatter(rich_people.PercentWhite, rich_people.MedianHouseholdIncome, c=cluster(X), s=50)

# %%
well_off_people = city_data[['City','MedianHouseholdIncome','PercentWhite', 'TotalPopulation']][city_data.MedianHouseholdIncome >= 100000]
print "Mean white: " + str(np.mean(well_off_people.PercentWhite))
print "Median white: " + str(np.median(well_off_people.PercentWhite))
well_off_people
# Out:
# Mean white: 72.6746987952
# Median white: 76.2
#                       City  MedianHouseholdIncome  PercentWhite  \
# 39           MountainBrook                 136447          96.4
# 132            AgouraHills                 108820          78.4
# 158                Belmont                 100417          57.1
# 169              Calabasas                 118182          75.9
# 183             ChinoHills                 101905          34.7
# 188                Clayton                 131991          78.4
# 204              Cupertino                 124825          31.8
# 216                 Dublin                 111481          50.6
# 218               Eastvale                 115025          24.9
# 236             FosterCity                 115053          41.3
# 260           HermosaBeach                 102289          79.7
# 274     LaCa�adaFlintridge                 148214          67.0
# 275              Lafayette                 134871          80.9
# 278           LagunaNiguel                 100480          71.9
# 306               LosAltos                 151856          66.9
# 312                 Malibu                 132926          84.0
# 313         ManhattanBeach                 132752          79.7
# 321              MenloPark                 111244          62.2
# 324             MillValley                 109759          84.1
# 333               Moorpark                 103009          60.6
# 342           NewportBeach                 108946          82.7
# 352                 Orinda                 157500          79.0
# 360               PaloAlto                 122532          60.5
# 361     PalosVerdesEstates                 159038          72.7
# 369               Piedmont                 199304          72.6
# 375             Pleasanton                 118713          60.1
# 383      RanchoPalosVerdes                 116643          55.8
# 384   RanchoSantaMargarita                 104167          68.0
# 406              SanCarlos                 118865          76.2
# 420              SanMarino                 154318          39.4
# ...                    ...                    ...           ...
# 1542               Hoboken                 104789          70.7
# 1557                Summit                 118565          74.4
# 1622                   Rye                 142469          86.0
# 1735                Dublin                 113361          78.7
# 1761                Hudson                 117361          90.3
# 1788            Montgomery                 114173          89.1
# 1811                Powell                 132656          88.2
# 1924           HappyValley                 100647          76.0
# 2037             Brentwood                 127596          89.5
# 2052                German                 112979          86.6
# 2104              Bellaire                 155423          76.0
# 2125           Colleyville                 159982          80.7
# 2128               Coppell                 106981          65.5
# 2156           Friendswood                 104216          75.6
# 2157                Frisco                 105647          67.3
# 2176              Highland                 129977          88.1
# 2187                Keller                 115228          85.5
# 2194               Lakeway                 100844          86.8
# 2223                Murphy                 112408          53.2
# 2270             Southlake                 183441          87.8
# 2273             SugarLand                 103265          44.9
# 2285        UniversityPark                 151862          90.0
# 2296   WestUniversityPlace                 186703          81.2
# 2313              Highland                 103720          95.0
# 2356           FallsChurch                 120332          74.2
# 2412        LakeForestPark                 100972          84.9
# 2420          MercerIsland                 123328          76.4
# 2427             Newcastle                 106339          60.9
# 2438             Sammamish                 135432          71.8
# 2501                Mequon                 106519          90.4
#
#       TotalPopulation
# 39              20401
# 132             20353
# 158             25568
# 169             22839
# 183             74765
# 188             10856
# 204             57459
# 216             44171
# 218             53437
# 236             30133
# 260             19422
# 274             20248
# 275             23863
# 278             62855
# 306             28752
# 312             12746
# 313             34986
# 321             31669
# 324             13810
# 333             34100
# 342             84417
# 352             17599
# 360             63475
# 361             13412
# 369             10640
# 375             69220
# 383             41575
# 384             47769
# 406             28130
# 420             13131
# ...               ...
# 1542            48515
# 1557            21316
# 1622            15619
# 1735            40353
# 1761            22289
# 1788            10170
# 1811            11145
# 1924            13170
# 2037            36392
# 2052            38781
# 2104            16751
# 2125            22569
# 2128            38797
# 2156            35358
# 2157           110013
# 2176            14969
# 2187            38557
# 2194            11092
# 2223            16456
# 2270            26194
# 2273            77935
# 2285            23076
# 2296            14733
# 2313            14789
# 2356            11840
# 2412            12648
# 2420            22592
# 2427            10109
# 2438            44526
# 2501            23111
#
# [83 rows x 4 columns]

# %%
x = well_off_people.PercentWhite
y = well_off_people.MedianHouseholdIncome 
x = sm.add_constant(x)

clf = linear_model.LinearRegression()
clf.fit(x,y)

y_hat = clf.predict(x)

plt.scatter(well_off_people.PercentWhite,well_off_people.MedianHouseholdIncome,color="Black")
plt.plot(x.PercentWhite, y_hat, 'b', alpha=0.9)

print "R^2: ", clf.score(x,y)
# Out:
# R^2:  0.0154200672931

# %%
very_white_people = city_data[['City','MedianHouseholdIncome','PercentWhite', 'TotalPopulation']][city_data.PercentWhite >= 95]
print "Mean income: " + str(np.mean(very_white_people.MedianHouseholdIncome))
print "Median income: " + str(np.median(very_white_people.MedianHouseholdIncome))

very_white_people
# Out:
# Mean income: 50297.6290323
# Median income: 45624.5
#                  City  MedianHouseholdIncome  PercentWhite  TotalPopulation
# 39      MountainBrook                 136447          96.4            20401
# 569        CocoaBeach                  53951          95.0            11498
# 829         Effingham                  41942          96.0            12161
# 839            Herrin                  35485          95.7            12408
# 885        Washington                  63051          95.3            14755
# 890         WoodRiver                  49747          95.8            10712
# 895            Auburn                  42685          95.1            12512
# 915        Greensburg                  42278          95.2            11059
# 919        Huntington                  36973          95.5            17438
# 932      Martinsville                  34982          96.7            11924
# 937         NewCastle                  31744          96.1            18142
# 950            Wabash                  36641          97.3            10735
# 959             Boone                  45469          95.1            12724
# 961           Carroll                  45316          96.7            10077
# 973         Indianola                  53162          96.2            14688
# 981            Newton                  42348          96.3            15300
# 1164       PalmerTown                  50864          95.7            12161
# 1184           Alpena                  31805          96.2            10562
# 1200  EastGrandRapids                  99063          96.4            10743
# 1231       Marysville                  52588          96.4            10005
# 1276       Alexandria                  35050          95.6            11102
# 1306      FergusFalls                  38673          97.0            13258
# 1310      GrandRapids                  41931          96.2            10833
# 1332           NewUlm                  44214          96.1            13493
# 1354          Sartell                  66650          95.1            15175
# 1439          Jackson                  50132          96.0            13598
# 1480       Washington                  48884          95.6            13986
# 1492         Beatrice                  39215          95.8            12499
# 1518           Berlin                  38107          95.5            10126
# 1519        Claremont                  38846          97.5            13422
# ...               ...                    ...           ...              ...
# 1701              Bay                  80498          96.3            15617
# 1719           Celina                  39886          96.1            10408
# 1737         Eastlake                  53650          95.0            18760
# 1748         Franklin                  38528          96.0            11940
# 1751           Galion                  34934          96.5            10604
# 1755       Greenville                  32069          96.1            13230
# 1766        Lancaster                  38869          96.0            38768
# 1783           Mentor                  65044          95.2            47461
# 1789      MountVernon                  35609          95.1            16943
# 1791      NewFranklin                  61700          97.8            14253
# 1794      NorthCanton                  50572          95.4            17419
# 1798           Norton                  56645          96.6            12025
# 1818            Salem                  35853          97.6            12356
# 1820       SevenHills                  64737          95.8            11771
# 1847        Vermilion                  53610          95.5            10804
# 1964        Hermitage                  49034          95.6            16164
# 1968     LowerBurrell                  48818          96.9            11845
# 1979         St.Marys                  45780          97.7            13206
# 2031        Spearfish                  35476          95.4            10339
# 2079       SoddyDaisy                  47285          96.9            12567
# 2084       WhiteHouse                  66250          97.1            10036
# 2210        Lumberton                  66875          96.0            11633
# 2313         Highland                 103720          95.0            14789
# 2347          Rutland                  37297          95.5            16622
# 2465      Parkersburg                  33629          95.0            31646
# 2468           Vienna                  46200          95.2            10734
# 2477        Cedarburg                  70964          95.4            11417
# 2497        Marinette                  39095          95.4            11038
# 2504           Monroe                  40441          95.8            10874
# 2505          Muskego                  83994          95.9            23928
#
# [62 rows x 4 columns]

# %%
x = very_white_people.PercentWhite
y = very_white_people.MedianHouseholdIncome 
x = sm.add_constant(x)

clf = linear_model.LinearRegression()
clf.fit(x,y)

y_hat = clf.predict(x)

plt.scatter(very_white_people.PercentWhite,very_white_people.MedianHouseholdIncome,color="Black")
plt.plot(x.PercentWhite, y_hat, 'b', alpha=0.9)

print "R^2: ", clf.score(x,y)
# Out:
# R^2:  0.000676131502465
